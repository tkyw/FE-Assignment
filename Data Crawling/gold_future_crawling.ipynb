# %%
import yfinance as yf
from pandas_datareader import data as pdr
import pandas as pd
yf.pdr_override() # <== the override :-)

# %%
compaines = pdr.get_data_yahoo("GC=F", start="1999-01-01", end="2023-01-01")
compaines
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-08-30   273.899994   273.899994   273.899994   273.899994   273.899994
# 2000-08-31   274.799988   278.299988   274.799988   278.299988   278.299988
# 2000-09-01   277.000000   277.000000   277.000000   277.000000   277.000000
# 2000-09-05   275.799988   275.799988   275.799988   275.799988   275.799988
# 2000-09-06   274.200012   274.200012   274.200012   274.200012   274.200012
# ...                 ...          ...          ...          ...          ...
# 2022-12-23  1794.300049  1802.800049  1794.099976  1795.900024  1795.900024
# 2022-12-27  1803.400024  1826.300049  1803.400024  1814.800049  1814.800049
# 2022-12-28  1803.199951  1807.900024  1803.099976  1807.900024  1807.900024
# 2022-12-29  1805.800049  1819.500000  1805.800049  1819.500000  1819.500000
# ...

# %%
compaines.sort_index(ascending=False).to_clipboard(excel=True)
